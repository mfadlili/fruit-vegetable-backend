# %%
import numpy as np
import base64
import json
import pickle

def im2json(im):
    """Convert a Numpy array to JSON string"""
    imdata = pickle.dumps(im)
    jstr = json.dumps({"image": base64.b64encode(imdata).decode('ascii')})
    return jstr

def json2im(jstr):
    """Convert a JSON string back to a Numpy array"""
    load = json.loads(jstr)
    imdata = base64.b64decode(load['image'])
    im = pickle.loads(imdata)
    return im

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('apel.jpg')
imgplot = plt.imshow(img)

plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
type(img)
# Out:
# numpy.ndarray

# %%
file_to_json = im2json(img)

# %%
import requests
URL = 'https://fruits-vegetables-backend.herokuapp.com/fruit'
r = requests.post(URL, json=file_to_json)
hasil = r.json()['result']

# %%
hasil
# Out:
# 'Fresh Apple'

# %% [markdown]
# ### Run cells below if you the app.py locally

# %%
import requests
URL = 'http://127.0.0.1:5000/fruit'
r = requests.post(URL, json=file_to_json)
hasil = r.json()['result']

# %%
hasil
